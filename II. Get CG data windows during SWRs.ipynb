# %% [markdown]
# <br>
#
#
# # Collect CG data windows during SWR occurrence
#
# In this notebook we collect all CG activity windows during previously detected ripples.
#
# To do it, it:
# - Applies an exclusion window of 500 ms before to prevent contamination - so only ripples separated by more that 500 ms will be included in the analysis;
# - Collects necessary CG data and stores it in a dataframe

# %% [markdown]
# ### Imports

# %%
import pandas as pd
from functools import reduce
import os
import re
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import random
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <br>
#
# ### Define function(s)

# %%
def associate_ripples_with_chunk_file(row, chunk_info):
    
    '''
    Add chunk number to row using the chunk_info dataframe
    '''
    mask = (chunk_info['session']==row['path']) & \
        (
        # check for ripple start time
        ((chunk_info['t_first']<=row['ephys_tfirst']) & (chunk_info['t_final']>=row['ephys_tfirst'])) |\
        # check for ripple end time
        ((chunk_info['t_first']<=row['ephys_tlast']) & (chunk_info['t_final']>=row['ephys_tlast']))
        )
    
    # Get match(es)
    chunk=chunk_info[mask]
    
    if  len(chunk)==1:
        return pd.Series([chunk.nr.iloc[0], np.nan])
    elif len(chunk==2):
        return pd.Series([chunk.nr.iloc[0], chunk.nr.iloc[1]])
    else:
        return np.nan, np.nan

# %% [markdown]
# <br>
#
# ### Open datasets

# %%
main_path = '/VOLUMES/E/EPHYS/data/'    
local_path = 'PreProcessedData/'

# Open SWR events
ripples_classified = pd.read_csv(os.path.join(local_path, 'ripples_classified.csv'))

# %% [markdown]
# <br>
#
# ### Apply exclusion window
# Only keep ripples with no ripple occurrence in the x s before

# %%
window_size = 0.5

# %%
# Add exclusion window
ripples_sorted=ripples_classified.sort_values(['session_code','start_time'], ascending=True)
# Calculate time from previous event detected
ripples_sorted['time_diff_to_previous']=ripples_sorted.groupby(['session_code']).start_time.diff()
# Calculate time to following event detected
ripples_sorted['time_diff_to_next']=ripples_sorted.groupby(['session_code']).start_time.diff(-1)

# %%
# Create exclusion mask
exclusion_mask =(
    ((ripples_sorted.time_diff_to_previous>=window_size) & \
     (ripples_sorted.time_diff_to_next <= - window_size)) |\
    # for first ripple of sessions
    ((ripples_sorted.time_diff_to_previous.isna()) & \
     (ripples_sorted.time_diff_to_next <= - window_size)) |\
    # for last ripple of sessions
    ((ripples_sorted.time_diff_to_previous >= window_size) & \
     (ripples_sorted.time_diff_to_next.isna()))
)

# Get ripples for analysis
ripples_analysis=ripples_sorted[exclusion_mask]

# %%
len(ripples_analysis)
# Out:
# 628

# %%
ripples_analysis.head()
# Out:
#      start_time    end_time  trial_nr  outcome run_type rat_code  \
# 706  127.722667  127.870000       1.0      1.0        S      MAG
# 707  129.012333  129.256000       1.0      1.0        S      MAG
# 710  139.889333  139.945000       1.0      1.0        S      MAG
# 711  145.028000  145.082667       1.0      1.0        S      MAG
# 712  149.383667  149.442000       1.0      1.0        S      MAG
#
#        session_code    x_ripple    y_ripple  duration_sec  duration_ms  \
# 706  20190126160731  179.647251  185.001791      0.147333   147.333333
# 707  20190126160731  179.584625  183.255619      0.243667   243.666667
# 710  20190126160731  207.251575  142.120470      0.055667    55.666667
# 711  20190126160731  178.555320  172.187209      0.054667    54.666667
# 712  20190126160731  178.333350  169.518474      0.058333    58.333333
#
#       phase  time_diff_to_previous  time_diff_to_next
# 706  Sample               3.162333          -1.289667
# 707  Sample               1.289667          -9.183333
# 710  Sample               1.380000          -5.138667
# 711  Sample               5.138667          -4.355667
# 712  Sample               4.355667        -111.420000

# %% [markdown]
# <br>
#
# ### Label ripples by chunk
#
# So we only need to open CG data from the chunks required

# %%
folders=os.listdir(main_path)

# Add path to each ripple
ripples_analysis['path']=ripples_analysis.apply(lambda x: 
                                            [f for f in folders if str(x.session_code) in f][0], 
                                            axis=1)

# %%
chunk_info = pd.DataFrame(columns=['session', 'nr', 't_first', 't_final'])

# For each path and ephys csv file get first and last timestamps
for folder in ripples_analysis.path.unique():
    
    timestamps_path = os.path.join(main_path, folder, 'Ephys_timestamps')
    
    for csv in os.listdir(timestamps_path):
        
        # Get first and last timestamps from each ephys timestamps csv
        csv_content = pd.read_csv(os.path.join(timestamps_path, csv))
        t1 = csv_content.head(1)['0'].iloc[0]
        tn = csv_content.tail(1)['0'].iloc[0]
        # Store all info in dataframe
        row = pd.DataFrame([{
            'session':folder, 
            'nr': re.search(r'([0-9]{1,2})', csv).group(1),
            't_first': t1,
            't_final': tn}])
        chunk_info = pd.concat([chunk_info, row])

chunk_info = chunk_info.reset_index(drop=True)

# %%
window = .5

# %%
# Calculate timestamps to read for each ripple
ripples_analysis['ephys_tfirst']=ripples_analysis['start_time']-window
ripples_analysis['ephys_tlast']=ripples_analysis['start_time']+window

# %%
#  Add chunk number to row using the chunk_info dataframe based on start and end time of ech ripple
ripples_analysis[['chunk_start', 'chunk_end']]=ripples_analysis.apply(associate_ripples_with_chunk_file, args=(chunk_info,), axis=1)

# %%
# Order by dataset and label ripple events
# This will be the ref_id to cross between ripples_analysis and the dataframe containing ephys data
ripples_analysis.sort_values(by=['path', 'chunk_start'], inplace=True)
ripples_analysis['ripple_nr']=range(0,len(ripples_analysis))

# %% [markdown]
# <br>
# <br>
#
# ### Get data from CG tetrodes
#
# This section includes:
# - Order ripples_analysis by dataset and label ripple events (numbering);
# - For each dataset x tt x chunk combination, open the tetrode data and collect 500 ms before and after each event. Store in a dataframe;
# - Storage of each CG activity data into a dictionary __data_merged__ containing the ephys data sorroundingthe detected event. Each key holds the CG ephys data for 1 ripple
# - __ripple_analysis__ will still hold the properties of each event.

# %%
# Create list with CG tetrode folder names
cg_tetrodes =['TT{}'.format(tt_nr) for tt_nr in range(1,15)]
cg_tetrodes
# Out:
# ['TT1',
#  'TT2',
#  'TT3',
#  'TT4',
#  'TT5',
#  'TT6',
#  'TT7',
#  'TT8',
#  'TT9',
#  'TT10',
#  'TT11',
#  'TT12',
#  'TT13',
#  'TT14']

# %%
ripples_analysis.head()
# Out:
#      start_time   end_time  trial_nr  outcome run_type rat_code  \
# 816    83.75725   83.81275       1.0      1.0        S      HOM
# 872   492.71775  492.79775       4.0      1.0        S      HOM
# 875   550.10425  550.15575       4.0      1.0        T      HOM
# 876   551.16475  551.18825       4.0      1.0        T      HOM
# 877   642.73825  642.79525       5.0      1.0        T      HOM
#
#        session_code    x_ripple    y_ripple  duration_sec  duration_ms  \
# 816  20191113131818  142.895008  123.167376        0.0555         55.5
# 872  20191113131818  181.876754  188.205562        0.0800         80.0
# 875  20191113131818  185.688022   23.871025        0.0515         51.5
# 876  20191113131818  183.437648   21.867660        0.0235         23.5
# 877  20191113131818   32.472432  117.420806        0.0570         57.0
#
#                   phase  time_diff_to_previous  time_diff_to_next  \
# 816              Sample                    NaN           -17.7710
# 872              Sample                53.5890            -2.1755
# 875  Test (Past-choice)                54.8125            -1.0605
# 876  Test (Past-choice)                 1.0605           -91.5735
# 877               Delay                91.5735            -3.0075
#
#                                       path  ephys_tfirst  ephys_tlast  \
# 816  HOMERO_DNMP16_20trials_20191113131818      83.25725     84.25725
# 872  HOMERO_DNMP16_20trials_20191113131818     492.21775    493.21775
# 875  HOMERO_DNMP16_20trials_20191113131818     549.60425    550.60425
# 876  HOMERO_DNMP16_20trials_20191113131818     550.66475    551.66475
# 877  HOMERO_DNMP16_20trials_20191113131818     642.23825    643.23825
#
#     chunk_start chunk_end  ripple_nr
# 816           1       NaN          0
# 872          10       NaN          1
# 875          12       NaN          2
# 876          12       NaN          3
# 877          14       NaN          4

# %%
ripples_analysis.ripple_nr.nunique()
# Out:
# 628

# %% [markdown]
# ### SOME DATASETS DONT HAVE ALL TT FOLDERS FROM CG. NEED TO FETCH

# %%
from functools import reduce

# %%
def fetch_cg_data(ripple, chunk):
    
    '''
    Fetches the CG data for the given chunk, for all TTs available. 
    Returns a dataframe with ripple nr and timestamp as index, TT as column and ephys data as values.    
    '''
    
    df_list = []
    
    # -- Read CG data from tetrodes
    tt_folders = [f for f in os.listdir(os.path.join(main_path, ripple.path)) if f in cg_tetrodes]

    # -- Read timestamps
    timestamps = pd.read_csv(
                        os.path.join(
                            main_path,
                            ripple.path,
                            'Ephys_timestamps', 
                            'timestamps_chunk{}.csv'.format(chunk)
                        )
                    )
       
        
    for folder in tt_folders:
        
        file_to_read = '{}_chunk{}.csv'.format(folder, chunk)          
                
        # Get ripples ephys from that chunk    
        chunk_data = pd.read_csv(os.path.join(
                main_path, 
                ripple.path, 
                folder,
                file_to_read))
                
        # Timestamps and chunk data must be the same length. 
        # Otherwise they might be wrongly paired or have differences due to crashes
        try:
            assert len(chunk_data)==len(timestamps)
        except: 
            print("Length difference found! Chunk len:{}, Timestamps len: {}".format(
            len(chunk_data), len(timestamps)))
            continue
                                
        # Get rows to read from timestamps file
        timestamps_ripple = timestamps.loc[timestamps['0'].between(
                ripple['ephys_tfirst'], ripple['ephys_tlast']), '0']
                    
        indices_to_read=timestamps_ripple.index.tolist()
           
        
        # Get chunk data using rows_to_read - read first channel (0 is an index)
        ripple_data = chunk_data.iloc[indices_to_read, 1].values
                      
        # Store into a multi-index dataframe
        iterables = [[ripple['ripple_nr']], timestamps_ripple.values.tolist()]
        multi_index = pd.MultiIndex.from_product(
                        iterables, 
                        names=['ripple_nr', 'timestamp'])
                    
        tt_stored = pd.DataFrame(ripple_data, index=multi_index, columns=[folder])
        
        df_list.append(tt_stored)  
     
    
    # Merge DataFrames in list of dataframes        
    all_tts_stored = reduce(
                        lambda left, right:     
                             pd.merge(left , right, on = ['ripple_nr', 'timestamp'], how = 'left'),
                         df_list
                    )
    
    return all_tts_stored

# %%
def collect_cg_data_for_ripple(ripple):
    
    ''' 
    For each ripple it collects all CG data for the given window, for all chunks required and TTs available   
    Returns a dataframe with ripple_nr and timestamp as index, TT as column and ephys points as values
    '''

    # Chunks to open for ripple
    chunks_to_open = ripple[['chunk_start', 'chunk_end']].dropna().unique()
    
    print('RIPPLE NR: {}'.format(ripple.ripple_nr))
    
    for chunk in chunks_to_open:
        print('---- CHUNK: {}'.format(chunk))
        
        # Fetches all data for ripple windown in chunk (all TTs)
        data = fetch_cg_data(ripple, chunk)
         
        # In case there is more than 1 chunk opened for a given ripple, concat data
        try:
            all_data = pd.concat([all_data, data])
        except:
            all_data = data
          
    
    return all_data

# %%
data_list = []

for i, row in ripples_analysis.iterrows():
    
    ripple_cg_data = collect_cg_data_for_ripple(row)
    data_list.append(ripple_cg_data)
# Out:
# RIPPLE NR: 0
# ---- CHUNK: 1
# RIPPLE NR: 1
# ---- CHUNK: 10
# RIPPLE NR: 2
# ---- CHUNK: 12
# RIPPLE NR: 3
# ---- CHUNK: 12
# RIPPLE NR: 4
# ---- CHUNK: 14
# RIPPLE NR: 5
# ---- CHUNK: 14
# RIPPLE NR: 6
# ---- CHUNK: 14
# RIPPLE NR: 7
# ---- CHUNK: 14
# RIPPLE NR: 8
# ---- CHUNK: 14
# RIPPLE NR: 9
# ---- CHUNK: 14
# RIPPLE NR: 10
# ---- CHUNK: 14
# RIPPLE NR: 11
# ---- CHUNK: 14
# RIPPLE NR: 12
# ---- CHUNK: 15
# RIPPLE NR: 13
# ---- CHUNK: 15
# RIPPLE NR: 14
# ---- CHUNK: 16
# RIPPLE NR: 15
# ---- CHUNK: 17
# RIPPLE NR: 16
# ---- CHUNK: 17
# RIPPLE NR: 17
# ---- CHUNK: 17
# RIPPLE NR: 18
# ---- CHUNK: 17
# RIPPLE NR: 19
# ---- CHUNK: 2
# RIPPLE NR: 20
# ---- CHUNK: 2
# RIPPLE NR: 21
# ---- CHUNK: 20
# RIPPLE NR: 22
# ---- CHUNK: 21
# RIPPLE NR: 23
# ---- CHUNK: 21
# RIPPLE NR: 24
# ---- CHUNK: 21
# RIPPLE NR: 25
# ---- CHUNK: 21
# RIPPLE NR: 26
# ---- CHUNK: 22
# RIPPLE NR: 27
# ---- CHUNK: 23
# RIPPLE NR: 28
# ---- CHUNK: 23
# RIPPLE NR: 29
# ---- CHUNK: 23
# ---- CHUNK: 24
# RIPPLE NR: 30
# ---- CHUNK: 25
# RIPPLE NR: 31
# ---- CHUNK: 25
# RIPPLE NR: 32
# ---- CHUNK: 25
# RIPPLE NR: 33
# ---- CHUNK: 25
# RIPPLE NR: 34
# ---- CHUNK: 25
# RIPPLE NR: 35
# ---- CHUNK: 25
# RIPPLE NR: 36
# ---- CHUNK: 27
# RIPPLE NR: 37
# ---- CHUNK: 27
# RIPPLE NR: 38
# ---- CHUNK: 27
# RIPPLE NR: 39
# ---- CHUNK: 27
# RIPPLE NR: 40
# ---- CHUNK: 28
# RIPPLE NR: 41
# ---- CHUNK: 3
# RIPPLE NR: 42
# ---- CHUNK: 3
# RIPPLE NR: 43
# ---- CHUNK: 30
# RIPPLE NR: 44
# ---- CHUNK: 31
# RIPPLE NR: 45
# ---- CHUNK: 33
# RIPPLE NR: 46
# ---- CHUNK: 33
# RIPPLE NR: 47
# ---- CHUNK: 36
# RIPPLE NR: 48
# ---- CHUNK: 37
# RIPPLE NR: 49
# ---- CHUNK: 37
# RIPPLE NR: 50
# ---- CHUNK: 37
# RIPPLE NR: 51
# ---- CHUNK: 37
# RIPPLE NR: 52
# ---- CHUNK: 37
# RIPPLE NR: 53
# ---- CHUNK: 38
# RIPPLE NR: 54
# ---- CHUNK: 39
# RIPPLE NR: 55
# ---- CHUNK: 4
# RIPPLE NR: 56
# ---- CHUNK: 4
# RIPPLE NR: 57
# ---- CHUNK: 4
# RIPPLE NR: 58
# ---- CHUNK: 42
# RIPPLE NR: 59
# ---- CHUNK: 46
# RIPPLE NR: 60
# ---- CHUNK: 48
# RIPPLE NR: 61
# ---- CHUNK: 48
# RIPPLE NR: 62
# ---- CHUNK: 49
# RIPPLE NR: 63
# ---- CHUNK: 49
# RIPPLE NR: 64
# ---- CHUNK: 5
# RIPPLE NR: 65
# ---- CHUNK: 5
# RIPPLE NR: 66
# ---- CHUNK: 51
# RIPPLE NR: 67
# ---- CHUNK: 51
# RIPPLE NR: 68
# ---- CHUNK: 53
# RIPPLE NR: 69
# ---- CHUNK: 53
# RIPPLE NR: 70
# ---- CHUNK: 6
# ---- CHUNK: 7
# RIPPLE NR: 71
# ---- CHUNK: 7
# RIPPLE NR: 72
# ---- CHUNK: 7
# RIPPLE NR: 73
# ---- CHUNK: 8
# RIPPLE NR: 74
# ---- CHUNK: 9
# RIPPLE NR: 75
# ---- CHUNK: 10
# RIPPLE NR: 76
# ---- CHUNK: 10
# RIPPLE NR: 77
# ---- CHUNK: 10
# RIPPLE NR: 78
# ---- CHUNK: 10
# RIPPLE NR: 79
# ---- CHUNK: 11
# RIPPLE NR: 80
# ---- CHUNK: 11
# RIPPLE NR: 81
# ---- CHUNK: 12
# RIPPLE NR: 82
# ---- CHUNK: 13
# RIPPLE NR: 83
# ---- CHUNK: 13
# RIPPLE NR: 84
# ---- CHUNK: 14
# RIPPLE NR: 85
# ---- CHUNK: 14
# RIPPLE NR: 86
# ---- CHUNK: 14
# RIPPLE NR: 87
# ---- CHUNK: 15
# RIPPLE NR: 88
# ---- CHUNK: 15
# RIPPLE NR: 89
# ---- CHUNK: 15
# RIPPLE NR: 90
# ---- CHUNK: 16
# RIPPLE NR: 91
# ---- CHUNK: 17
# RIPPLE NR: 92
# ---- CHUNK: 17
# RIPPLE NR: 93
# ---- CHUNK: 17
# RIPPLE NR: 94
# ---- CHUNK: 17
# RIPPLE NR: 95
# ---- CHUNK: 18
# RIPPLE NR: 96
# ---- CHUNK: 18
# RIPPLE NR: 97
# ---- CHUNK: 18
# RIPPLE NR: 98
# ---- CHUNK: 19
# RIPPLE NR: 99
# ---- CHUNK: 19
# RIPPLE NR: 100
# ---- CHUNK: 20
# RIPPLE NR: 101
# ---- CHUNK: 21
# RIPPLE NR: 102
# ---- CHUNK: 21
# RIPPLE NR: 103
# ---- CHUNK: 23
# RIPPLE NR: 104
# ---- CHUNK: 24
# RIPPLE NR: 105
# ---- CHUNK: 24
# RIPPLE NR: 106
# ---- CHUNK: 24
# RIPPLE NR: 107
# ---- CHUNK: 26
# RIPPLE NR: 108
# ---- CHUNK: 26
# RIPPLE NR: 109
# ---- CHUNK: 28
# RIPPLE NR: 110
# ---- CHUNK: 28
# RIPPLE NR: 111
# ---- CHUNK: 30
# RIPPLE NR: 112
# ---- CHUNK: 30
# RIPPLE NR: 113
# ---- CHUNK: 30
# RIPPLE NR: 114
# ---- CHUNK: 31
# RIPPLE NR: 115
# ---- CHUNK: 31
# RIPPLE NR: 116
# ---- CHUNK: 32
# RIPPLE NR: 117
# ---- CHUNK: 32
# RIPPLE NR: 118
# ---- CHUNK: 32
# RIPPLE NR: 119
# ---- CHUNK: 33
# RIPPLE NR: 120
# ---- CHUNK: 34
# RIPPLE NR: 121
# ---- CHUNK: 34
# RIPPLE NR: 122
# ---- CHUNK: 34
# RIPPLE NR: 123
# ---- CHUNK: 36
# RIPPLE NR: 124
# ---- CHUNK: 37
# RIPPLE NR: 125
# ---- CHUNK: 37
# RIPPLE NR: 126
# ---- CHUNK: 37
# RIPPLE NR: 127
# ---- CHUNK: 39
# RIPPLE NR: 128
# ---- CHUNK: 39
# RIPPLE NR: 129
# ---- CHUNK: 39
# RIPPLE NR: 130
# ---- CHUNK: 4
# RIPPLE NR: 131
# ---- CHUNK: 40
# RIPPLE NR: 132
# ---- CHUNK: 40
# RIPPLE NR: 133
# ---- CHUNK: 41
# RIPPLE NR: 134
# ---- CHUNK: 41
# RIPPLE NR: 135
# ---- CHUNK: 43
# RIPPLE NR: 136
# ---- CHUNK: 43
# RIPPLE NR: 137
# ---- CHUNK: 43
# RIPPLE NR: 138
# ---- CHUNK: 43
# RIPPLE NR: 139
# ---- CHUNK: 43
# RIPPLE NR: 140
# ---- CHUNK: 43
# RIPPLE NR: 141
# ---- CHUNK: 43
# RIPPLE NR: 142
# ---- CHUNK: 44
# RIPPLE NR: 143
# ---- CHUNK: 44
# RIPPLE NR: 144
# ---- CHUNK: 46
# RIPPLE NR: 145
# ---- CHUNK: 48
# RIPPLE NR: 146
# ---- CHUNK: 48
# RIPPLE NR: 147
# ---- CHUNK: 48
# RIPPLE NR: 148
# ---- CHUNK: 49
# RIPPLE NR: 149
# ---- CHUNK: 50
# RIPPLE NR: 150
# ---- CHUNK: 50
# RIPPLE NR: 151
# ---- CHUNK: 50
# RIPPLE NR: 152
# ---- CHUNK: 50
# RIPPLE NR: 153
# ---- CHUNK: 50
# RIPPLE NR: 154
# ---- CHUNK: 50
# RIPPLE NR: 155
# ---- CHUNK: 50
# RIPPLE NR: 156
# ---- CHUNK: 50
# RIPPLE NR: 157
# ---- CHUNK: 51
# RIPPLE NR: 158
# ---- CHUNK: 51
# RIPPLE NR: 159
# ---- CHUNK: 51
# RIPPLE NR: 160
# ---- CHUNK: 51
# RIPPLE NR: 161
# ---- CHUNK: 51
# RIPPLE NR: 162
# ---- CHUNK: 51
# RIPPLE NR: 163
# ---- CHUNK: 51
# RIPPLE NR: 164
# ---- CHUNK: 51
# RIPPLE NR: 165
# ---- CHUNK: 51
# RIPPLE NR: 166
# ---- CHUNK: 51
# ---- CHUNK: 52
# RIPPLE NR: 167
# ---- CHUNK: 52
# RIPPLE NR: 168
# ---- CHUNK: 53
# RIPPLE NR: 169
# ---- CHUNK: 53
# RIPPLE NR: 170
# ---- CHUNK: 53
# RIPPLE NR: 171
# ---- CHUNK: 54
# RIPPLE NR: 172
# ---- CHUNK: 54
# RIPPLE NR: 173
# ---- CHUNK: 54
# RIPPLE NR: 174
# ---- CHUNK: 55
# RIPPLE NR: 175
# ---- CHUNK: 56
# RIPPLE NR: 176
# ---- CHUNK: 58
# RIPPLE NR: 177
# ---- CHUNK: 58
# RIPPLE NR: 178
# ---- CHUNK: 58
# RIPPLE NR: 179
# ---- CHUNK: 58
# RIPPLE NR: 180
# ---- CHUNK: 59
# RIPPLE NR: 181
# ---- CHUNK: 59
# RIPPLE NR: 182
# ---- CHUNK: 59
# RIPPLE NR: 183
# ---- CHUNK: 59
# RIPPLE NR: 184
# ---- CHUNK: 59
# RIPPLE NR: 185
# ---- CHUNK: 60
# RIPPLE NR: 186
# ---- CHUNK: 61
# RIPPLE NR: 187
# ---- CHUNK: 62
# RIPPLE NR: 188
# ---- CHUNK: 64
# RIPPLE NR: 189
# ---- CHUNK: 64
# RIPPLE NR: 190
# ---- CHUNK: 64
# RIPPLE NR: 191
# ---- CHUNK: 65
# RIPPLE NR: 192
# ---- CHUNK: 65
# RIPPLE NR: 193
# ---- CHUNK: 65
# RIPPLE NR: 194
# ---- CHUNK: 65
# RIPPLE NR: 195
# ---- CHUNK: 66
# RIPPLE NR: 196
# ---- CHUNK: 66
# RIPPLE NR: 197
# ---- CHUNK: 66
# RIPPLE NR: 198
# ---- CHUNK: 66
# RIPPLE NR: 199
# ---- CHUNK: 67
# RIPPLE NR: 200
# ---- CHUNK: 67
# RIPPLE NR: 201
# ---- CHUNK: 67
# RIPPLE NR: 202
# ---- CHUNK: 68
# RIPPLE NR: 203
# ---- CHUNK: 68
# RIPPLE NR: 204
# ---- CHUNK: 68
# RIPPLE NR: 205
# ---- CHUNK: 69
# RIPPLE NR: 206
# ---- CHUNK: 69
# RIPPLE NR: 207
# ---- CHUNK: 69
# RIPPLE NR: 208
# ---- CHUNK: 7
# RIPPLE NR: 209
# ---- CHUNK: 70
# RIPPLE NR: 210
# ---- CHUNK: 70
# RIPPLE NR: 211
# ---- CHUNK: 70
# RIPPLE NR: 212
# ---- CHUNK: 70
# RIPPLE NR: 213
# ---- CHUNK: 71
# RIPPLE NR: 214
# ---- CHUNK: 71
# RIPPLE NR: 215
# ---- CHUNK: 72
# RIPPLE NR: 216
# ---- CHUNK: 72
# RIPPLE NR: 217
# ---- CHUNK: 72
# RIPPLE NR: 218
# ---- CHUNK: 73
# RIPPLE NR: 219
# ---- CHUNK: 73
# RIPPLE NR: 220
# ---- CHUNK: 75
# RIPPLE NR: 221
# ---- CHUNK: 76
# RIPPLE NR: 222
# ---- CHUNK: 77
# RIPPLE NR: 223
# ---- CHUNK: 78
# RIPPLE NR: 224
# ---- CHUNK: 8
# RIPPLE NR: 225
# ---- CHUNK: 80
# RIPPLE NR: 226
# ---- CHUNK: 80
# RIPPLE NR: 227
# ---- CHUNK: 80
# RIPPLE NR: 228
# ---- CHUNK: 80
# ---- CHUNK: 81
# RIPPLE NR: 229
# ---- CHUNK: 82
# RIPPLE NR: 230
# ---- CHUNK: 82
# RIPPLE NR: 231
# ---- CHUNK: 82
# RIPPLE NR: 232
# ---- CHUNK: 82
# RIPPLE NR: 233
# ---- CHUNK: 82
# RIPPLE NR: 234
# ---- CHUNK: 82
# RIPPLE NR: 235
# ---- CHUNK: 83
# RIPPLE NR: 236
# ---- CHUNK: 84
# RIPPLE NR: 237
# ---- CHUNK: 85
# RIPPLE NR: 238
# ---- CHUNK: 85
# RIPPLE NR: 239
# ---- CHUNK: 86
# RIPPLE NR: 240
# ---- CHUNK: 87
# RIPPLE NR: 241
# ---- CHUNK: 87
# RIPPLE NR: 242
# ---- CHUNK: 87
# RIPPLE NR: 243
# ---- CHUNK: 87
# RIPPLE NR: 244
# ---- CHUNK: 87
# RIPPLE NR: 245
# ---- CHUNK: 87
# RIPPLE NR: 246
# ---- CHUNK: 87
# RIPPLE NR: 247
# ---- CHUNK: 87
# RIPPLE NR: 248
# ---- CHUNK: 87
# RIPPLE NR: 249
# ---- CHUNK: 87
# RIPPLE NR: 250
# ---- CHUNK: 87
# RIPPLE NR: 251
# ---- CHUNK: 87
# ---- CHUNK: 88
# RIPPLE NR: 252
# ---- CHUNK: 88
# RIPPLE NR: 253
# ---- CHUNK: 89
# RIPPLE NR: 254
# ---- CHUNK: 89
# RIPPLE NR: 255
# ---- CHUNK: 9
# RIPPLE NR: 256
# ---- CHUNK: 90
# RIPPLE NR: 257
# ---- CHUNK: 90
# RIPPLE NR: 258
# ---- CHUNK: 90
# RIPPLE NR: 259
# ---- CHUNK: 90
# RIPPLE NR: 260
# ---- CHUNK: 91
# RIPPLE NR: 261
# ---- CHUNK: 91
# RIPPLE NR: 262
# ---- CHUNK: 10
# RIPPLE NR: 263
# ---- CHUNK: 10
# RIPPLE NR: 264
# ---- CHUNK: 11
# RIPPLE NR: 265
# ---- CHUNK: 12
# RIPPLE NR: 266
# ---- CHUNK: 12
# ---- CHUNK: 13
# RIPPLE NR: 267
# ---- CHUNK: 13
# RIPPLE NR: 268
# ---- CHUNK: 16
# RIPPLE NR: 269
# ---- CHUNK: 16
# RIPPLE NR: 270
# ---- CHUNK: 16
# RIPPLE NR: 271
# ---- CHUNK: 17
# RIPPLE NR: 272
# ---- CHUNK: 19
# RIPPLE NR: 273
# ---- CHUNK: 21
# RIPPLE NR: 274
# ---- CHUNK: 23
# RIPPLE NR: 275
# ---- CHUNK: 23
# RIPPLE NR: 276
# ---- CHUNK: 23
# RIPPLE NR: 277
# ---- CHUNK: 23
# RIPPLE NR: 278
# ---- CHUNK: 23
# RIPPLE NR: 279
# ---- CHUNK: 25
# RIPPLE NR: 280
# ---- CHUNK: 27
# RIPPLE NR: 281
# ---- CHUNK: 27
# RIPPLE NR: 282
# ---- CHUNK: 29
# RIPPLE NR: 283
# ---- CHUNK: 31
# RIPPLE NR: 284
# ---- CHUNK: 33
# RIPPLE NR: 285
# ---- CHUNK: 35
# RIPPLE NR: 286
# ---- CHUNK: 37
# RIPPLE NR: 287
# ---- CHUNK: 37
# RIPPLE NR: 288
# ---- CHUNK: 37
# RIPPLE NR: 289
# ---- CHUNK: 4
# RIPPLE NR: 290
# ---- CHUNK: 4
# RIPPLE NR: 291
# ---- CHUNK: 4
# RIPPLE NR: 292
# ---- CHUNK: 4
# RIPPLE NR: 293
# ---- CHUNK: 4
# RIPPLE NR: 294
# ---- CHUNK: 41
# RIPPLE NR: 295
# ---- CHUNK: 43
# RIPPLE NR: 296
# ---- CHUNK: 43
# RIPPLE NR: 297
# ---- CHUNK: 43
# RIPPLE NR: 298
# ---- CHUNK: 43
# ---- CHUNK: 44
# RIPPLE NR: 299
# ---- CHUNK: 6
# RIPPLE NR: 300
# ---- CHUNK: 6
# RIPPLE NR: 301
# ---- CHUNK: 6
# RIPPLE NR: 302
# ---- CHUNK: 7
# RIPPLE NR: 303
# ---- CHUNK: 8
# RIPPLE NR: 304
# ---- CHUNK: 8
# RIPPLE NR: 305
# ---- CHUNK: 8
# RIPPLE NR: 306
# ---- CHUNK: 8
# RIPPLE NR: 307
# ---- CHUNK: 9
# RIPPLE NR: 308
# ---- CHUNK: 1
# RIPPLE NR: 309
# ---- CHUNK: 1
# RIPPLE NR: 310
# ---- CHUNK: 1
# RIPPLE NR: 311
# ---- CHUNK: 12
# RIPPLE NR: 312
# ---- CHUNK: 14
# RIPPLE NR: 313
# ---- CHUNK: 14
# RIPPLE NR: 314
# ---- CHUNK: 15
# RIPPLE NR: 315
# ---- CHUNK: 15
# RIPPLE NR: 316
# ---- CHUNK: 16
# RIPPLE NR: 317
# ---- CHUNK: 16
# ---- CHUNK: 17
# RIPPLE NR: 318
# ---- CHUNK: 17
# RIPPLE NR: 319
# ---- CHUNK: 17
# RIPPLE NR: 320
# ---- CHUNK: 17
# RIPPLE NR: 321
# ---- CHUNK: 17
# RIPPLE NR: 322
# ---- CHUNK: 17
# RIPPLE NR: 323
# ---- CHUNK: 17
# RIPPLE NR: 324
# ---- CHUNK: 21
# RIPPLE NR: 325
# ---- CHUNK: 21
# RIPPLE NR: 326
# ---- CHUNK: 21
# RIPPLE NR: 327
# ---- CHUNK: 25
# RIPPLE NR: 328
# ---- CHUNK: 26
# RIPPLE NR: 329
# ---- CHUNK: 26
# ---- CHUNK: 27
# RIPPLE NR: 330
# ---- CHUNK: 27
# RIPPLE NR: 331
# ---- CHUNK: 28
# RIPPLE NR: 332
# ---- CHUNK: 29
# RIPPLE NR: 333
# ---- CHUNK: 29
# RIPPLE NR: 334
# ---- CHUNK: 3
# RIPPLE NR: 335
# ---- CHUNK: 3
# RIPPLE NR: 336
# ---- CHUNK: 30
# RIPPLE NR: 337
# ---- CHUNK: 30
# RIPPLE NR: 338
# ---- CHUNK: 34
# RIPPLE NR: 339
# ---- CHUNK: 34
# RIPPLE NR: 340
# ---- CHUNK: 34
# RIPPLE NR: 341
# ---- CHUNK: 34
# RIPPLE NR: 342
# ---- CHUNK: 35
# RIPPLE NR: 343
# ---- CHUNK: 35
# RIPPLE NR: 344
# ---- CHUNK: 37
# RIPPLE NR: 345
# ---- CHUNK: 7
# RIPPLE NR: 346
# ---- CHUNK: 1
# RIPPLE NR: 347
# ---- CHUNK: 1
# RIPPLE NR: 348
# ---- CHUNK: 11
# RIPPLE NR: 349
# ---- CHUNK: 11
# RIPPLE NR: 350
# ---- CHUNK: 11
# RIPPLE NR: 351
# ---- CHUNK: 11
# RIPPLE NR: 352
# ---- CHUNK: 12
# RIPPLE NR: 353
# ---- CHUNK: 12
# RIPPLE NR: 354
# ---- CHUNK: 12
# ---- CHUNK: 13
# RIPPLE NR: 355
# ---- CHUNK: 13
# RIPPLE NR: 356
# ---- CHUNK: 13
# RIPPLE NR: 357
# ---- CHUNK: 13
# RIPPLE NR: 358
# ---- CHUNK: 13
# RIPPLE NR: 359
# ---- CHUNK: 13
# RIPPLE NR: 360
# ---- CHUNK: 13
# RIPPLE NR: 361
# ---- CHUNK: 14
# RIPPLE NR: 362
# ---- CHUNK: 14
# RIPPLE NR: 363
# ---- CHUNK: 15
# RIPPLE NR: 364
# ---- CHUNK: 15
# RIPPLE NR: 365
# ---- CHUNK: 15
# RIPPLE NR: 366
# ---- CHUNK: 15
# RIPPLE NR: 367
# ---- CHUNK: 15
# RIPPLE NR: 368
# ---- CHUNK: 17
# RIPPLE NR: 369
# ---- CHUNK: 17
# RIPPLE NR: 370
# ---- CHUNK: 17
# RIPPLE NR: 371
# ---- CHUNK: 17
# ---- CHUNK: 18
# RIPPLE NR: 372
# ---- CHUNK: 18
# RIPPLE NR: 373
# ---- CHUNK: 18
# RIPPLE NR: 374
# ---- CHUNK: 18
# RIPPLE NR: 375
# ---- CHUNK: 18
# RIPPLE NR: 376
# ---- CHUNK: 18
# RIPPLE NR: 377
# ---- CHUNK: 2
# RIPPLE NR: 378
# ---- CHUNK: 2
# RIPPLE NR: 379
# ---- CHUNK: 2
# RIPPLE NR: 380
# ---- CHUNK: 20
# RIPPLE NR: 381
# ---- CHUNK: 22
# RIPPLE NR: 382
# ---- CHUNK: 22
# RIPPLE NR: 383
# ---- CHUNK: 22
# RIPPLE NR: 384
# ---- CHUNK: 24
# RIPPLE NR: 385
# ---- CHUNK: 24
# RIPPLE NR: 386
# ---- CHUNK: 24
# RIPPLE NR: 387
# ---- CHUNK: 24
# RIPPLE NR: 388
# ---- CHUNK: 26
# RIPPLE NR: 389
# ---- CHUNK: 26
# RIPPLE NR: 390
# ---- CHUNK: 26
# RIPPLE NR: 391
# ---- CHUNK: 26
# RIPPLE NR: 392
# ---- CHUNK: 26
# RIPPLE NR: 393
# ---- CHUNK: 27
# RIPPLE NR: 394
# ---- CHUNK: 27
# RIPPLE NR: 395
# ---- CHUNK: 28
# RIPPLE NR: 396
# ---- CHUNK: 29
# RIPPLE NR: 397
# ---- CHUNK: 29
# RIPPLE NR: 398
# ---- CHUNK: 29
# RIPPLE NR: 399
# ---- CHUNK: 29
# RIPPLE NR: 400
# ---- CHUNK: 3
# RIPPLE NR: 401
# ---- CHUNK: 3
# RIPPLE NR: 402
# ---- CHUNK: 30
# ---- CHUNK: 31
# RIPPLE NR: 403
# ---- CHUNK: 31
# RIPPLE NR: 404
# ---- CHUNK: 31
# RIPPLE NR: 405
# ---- CHUNK: 32
# RIPPLE NR: 406
# ---- CHUNK: 33
# RIPPLE NR: 407
# ---- CHUNK: 34
# RIPPLE NR: 408
# ---- CHUNK: 34
# RIPPLE NR: 409
# ---- CHUNK: 34
# RIPPLE NR: 410
# ---- CHUNK: 34
# ---- CHUNK: 35
# RIPPLE NR: 411
# ---- CHUNK: 35
# RIPPLE NR: 412
# ---- CHUNK: 36
# RIPPLE NR: 413
# ---- CHUNK: 36
# RIPPLE NR: 414
# ---- CHUNK: 36
# RIPPLE NR: 415
# ---- CHUNK: 37
# RIPPLE NR: 416
# ---- CHUNK: 37
# RIPPLE NR: 417
# ---- CHUNK: 38
# RIPPLE NR: 418
# ---- CHUNK: 38
# RIPPLE NR: 419
# ---- CHUNK: 39
# RIPPLE NR: 420
# ---- CHUNK: 39
# RIPPLE NR: 421
# ---- CHUNK: 39
# RIPPLE NR: 422
# ---- CHUNK: 39
# RIPPLE NR: 423
# ---- CHUNK: 4
# RIPPLE NR: 424
# ---- CHUNK: 4
# RIPPLE NR: 425
# ---- CHUNK: 4
# RIPPLE NR: 426
# ---- CHUNK: 41
# RIPPLE NR: 427
# ---- CHUNK: 41
# RIPPLE NR: 428
# ---- CHUNK: 41
# RIPPLE NR: 429
# ---- CHUNK: 41
# RIPPLE NR: 430
# ---- CHUNK: 41
# RIPPLE NR: 431
# ---- CHUNK: 41
# RIPPLE NR: 432
# ---- CHUNK: 42
# RIPPLE NR: 433
# ---- CHUNK: 43
# RIPPLE NR: 434
# ---- CHUNK: 43
# RIPPLE NR: 435
# ---- CHUNK: 43
# RIPPLE NR: 436
# ---- CHUNK: 43
# RIPPLE NR: 437
# ---- CHUNK: 45
# RIPPLE NR: 438
# ---- CHUNK: 45
# RIPPLE NR: 439
# ---- CHUNK: 45
# RIPPLE NR: 440
# ---- CHUNK: 45
# RIPPLE NR: 441
# ---- CHUNK: 45
# RIPPLE NR: 442
# ---- CHUNK: 45
# RIPPLE NR: 443
# ---- CHUNK: 46
# RIPPLE NR: 444
# ---- CHUNK: 47
# RIPPLE NR: 445
# ---- CHUNK: 47
# RIPPLE NR: 446
# ---- CHUNK: 47
# RIPPLE NR: 447
# ---- CHUNK: 48
# RIPPLE NR: 448
# ---- CHUNK: 48
# RIPPLE NR: 449
# ---- CHUNK: 49
# RIPPLE NR: 450
# ---- CHUNK: 5
# RIPPLE NR: 451
# ---- CHUNK: 5
# RIPPLE NR: 452
# ---- CHUNK: 5
# RIPPLE NR: 453
# ---- CHUNK: 50
# RIPPLE NR: 454
# ---- CHUNK: 50
# RIPPLE NR: 455
# ---- CHUNK: 50
# RIPPLE NR: 456
# ---- CHUNK: 50
# RIPPLE NR: 457
# ---- CHUNK: 50
# RIPPLE NR: 458
# ---- CHUNK: 50
# RIPPLE NR: 459
# ---- CHUNK: 50
# RIPPLE NR: 460
# ---- CHUNK: 50
# RIPPLE NR: 461
# ---- CHUNK: 50
# RIPPLE NR: 462
# ---- CHUNK: 52
# RIPPLE NR: 463
# ---- CHUNK: 52
# RIPPLE NR: 464
# ---- CHUNK: 52
# RIPPLE NR: 465
# ---- CHUNK: 52
# RIPPLE NR: 466
# ---- CHUNK: 52
# RIPPLE NR: 467
# ---- CHUNK: 6
# RIPPLE NR: 468
# ---- CHUNK: 7
# RIPPLE NR: 469
# ---- CHUNK: 7
# RIPPLE NR: 470
# ---- CHUNK: 8
# RIPPLE NR: 471
# ---- CHUNK: 8
# RIPPLE NR: 472
# ---- CHUNK: 8
# RIPPLE NR: 473
# ---- CHUNK: 8
# RIPPLE NR: 474
# ---- CHUNK: 8
# ---- CHUNK: 9
# RIPPLE NR: 475
# ---- CHUNK: 9
# RIPPLE NR: 476
# ---- CHUNK: 9
# RIPPLE NR: 477
# ---- CHUNK: 9
# RIPPLE NR: 478
# ---- CHUNK: 9
# RIPPLE NR: 479
# ---- CHUNK: 9
# RIPPLE NR: 480
# ---- CHUNK: 9
# RIPPLE NR: 481
# ---- CHUNK: 9
# RIPPLE NR: 482
# ---- CHUNK: 10
# RIPPLE NR: 483
# ---- CHUNK: 10
# RIPPLE NR: 484
# ---- CHUNK: 10
# RIPPLE NR: 485
# ---- CHUNK: 11
# RIPPLE NR: 486
# ---- CHUNK: 12
# RIPPLE NR: 487
# ---- CHUNK: 12
# RIPPLE NR: 488
# ---- CHUNK: 12
# RIPPLE NR: 489
# ---- CHUNK: 14
# RIPPLE NR: 490
# ---- CHUNK: 14
# RIPPLE NR: 491
# ---- CHUNK: 14
# RIPPLE NR: 492
# ---- CHUNK: 2
# RIPPLE NR: 493
# ---- CHUNK: 2
# RIPPLE NR: 494
# ---- CHUNK: 2
# RIPPLE NR: 495
# ---- CHUNK: 2
# RIPPLE NR: 496
# ---- CHUNK: 3
# RIPPLE NR: 497
# ---- CHUNK: 3
# RIPPLE NR: 498
# ---- CHUNK: 4
# RIPPLE NR: 499
# ---- CHUNK: 4
# RIPPLE NR: 500
# ---- CHUNK: 4
# RIPPLE NR: 501
# ---- CHUNK: 4
# RIPPLE NR: 502
# ---- CHUNK: 6
# RIPPLE NR: 503
# ---- CHUNK: 7
# RIPPLE NR: 504
# ---- CHUNK: 10
# RIPPLE NR: 505
# ---- CHUNK: 10
# RIPPLE NR: 506
# ---- CHUNK: 10
# RIPPLE NR: 507
# ---- CHUNK: 10
# RIPPLE NR: 508
# ---- CHUNK: 12
# RIPPLE NR: 509
# ---- CHUNK: 12
# RIPPLE NR: 510
# ---- CHUNK: 13
# RIPPLE NR: 511
# ---- CHUNK: 13
# RIPPLE NR: 512
# ---- CHUNK: 13
# RIPPLE NR: 513
# ---- CHUNK: 14
# RIPPLE NR: 514
# ---- CHUNK: 15
# RIPPLE NR: 515
# ---- CHUNK: 15
# RIPPLE NR: 516
# ---- CHUNK: 15
# RIPPLE NR: 517
# ---- CHUNK: 15
# RIPPLE NR: 518
# ---- CHUNK: 17
# RIPPLE NR: 519
# ---- CHUNK: 17
# RIPPLE NR: 520
# ---- CHUNK: 17
# RIPPLE NR: 521
# ---- CHUNK: 17
# RIPPLE NR: 522
# ---- CHUNK: 18
# RIPPLE NR: 523
# ---- CHUNK: 18
# RIPPLE NR: 524
# ---- CHUNK: 2
# RIPPLE NR: 525
# ---- CHUNK: 2
# RIPPLE NR: 526
# ---- CHUNK: 2
# RIPPLE NR: 527
# ---- CHUNK: 21
# RIPPLE NR: 528
# ---- CHUNK: 21
# RIPPLE NR: 529
# ---- CHUNK: 21
# RIPPLE NR: 530
# ---- CHUNK: 23
# RIPPLE NR: 531
# ---- CHUNK: 24
# RIPPLE NR: 532
# ---- CHUNK: 24
# RIPPLE NR: 533
# ---- CHUNK: 24
# RIPPLE NR: 534
# ---- CHUNK: 3
# RIPPLE NR: 535
# ---- CHUNK: 3
# RIPPLE NR: 536
# ---- CHUNK: 3
# RIPPLE NR: 537
# ---- CHUNK: 3
# RIPPLE NR: 538
# ---- CHUNK: 4
# RIPPLE NR: 539
# ---- CHUNK: 4
# RIPPLE NR: 540
# ---- CHUNK: 4
# RIPPLE NR: 541
# ---- CHUNK: 5
# RIPPLE NR: 542
# ---- CHUNK: 5
# RIPPLE NR: 543
# ---- CHUNK: 6
# RIPPLE NR: 544
# ---- CHUNK: 6
# RIPPLE NR: 545
# ---- CHUNK: 6
# RIPPLE NR: 546
# ---- CHUNK: 8
# RIPPLE NR: 547
# ---- CHUNK: 10
# ---- CHUNK: 11
# RIPPLE NR: 548
# ---- CHUNK: 12
# RIPPLE NR: 549
# ---- CHUNK: 14
# RIPPLE NR: 550
# ---- CHUNK: 15
# RIPPLE NR: 551
# ---- CHUNK: 16
# RIPPLE NR: 552
# ---- CHUNK: 16
# RIPPLE NR: 553
# ---- CHUNK: 19
# RIPPLE NR: 554
# ---- CHUNK: 21
# RIPPLE NR: 555
# ---- CHUNK: 21
# RIPPLE NR: 556
# ---- CHUNK: 25
# RIPPLE NR: 557
# ---- CHUNK: 27
# RIPPLE NR: 558
# ---- CHUNK: 28
# RIPPLE NR: 559
# ---- CHUNK: 28
# RIPPLE NR: 560
# ---- CHUNK: 28
# RIPPLE NR: 561
# ---- CHUNK: 30
# RIPPLE NR: 562
# ---- CHUNK: 30
# RIPPLE NR: 563
# ---- CHUNK: 32
# RIPPLE NR: 564
# ---- CHUNK: 32
# RIPPLE NR: 565
# ---- CHUNK: 32
# RIPPLE NR: 566
# ---- CHUNK: 33
# RIPPLE NR: 567
# ---- CHUNK: 34
# RIPPLE NR: 568
# ---- CHUNK: 34
# RIPPLE NR: 569
# ---- CHUNK: 34
# RIPPLE NR: 570
# ---- CHUNK: 34
# RIPPLE NR: 571
# ---- CHUNK: 36
# RIPPLE NR: 572
# ---- CHUNK: 36
# RIPPLE NR: 573
# ---- CHUNK: 36
# RIPPLE NR: 574
# ---- CHUNK: 36
# ---- CHUNK: 37
# RIPPLE NR: 575
# ---- CHUNK: 39
# RIPPLE NR: 576
# ---- CHUNK: 39
# RIPPLE NR: 577
# ---- CHUNK: 4
# RIPPLE NR: 578
# ---- CHUNK: 4
# RIPPLE NR: 579
# ---- CHUNK: 4
# RIPPLE NR: 580
# ---- CHUNK: 4
# RIPPLE NR: 581
# ---- CHUNK: 4
# ---- CHUNK: 5
# RIPPLE NR: 582
# ---- CHUNK: 41
# RIPPLE NR: 583
# ---- CHUNK: 41
# RIPPLE NR: 584
# ---- CHUNK: 43
# RIPPLE NR: 585
# ---- CHUNK: 47
# RIPPLE NR: 586
# ---- CHUNK: 48
# RIPPLE NR: 587
# ---- CHUNK: 48
# RIPPLE NR: 588
# ---- CHUNK: 48
# RIPPLE NR: 589
# ---- CHUNK: 48
# RIPPLE NR: 590
# ---- CHUNK: 48
# RIPPLE NR: 591
# ---- CHUNK: 48
# RIPPLE NR: 592
# ---- CHUNK: 49
# RIPPLE NR: 593
# ---- CHUNK: 52
# ---- CHUNK: 53
# RIPPLE NR: 594
# ---- CHUNK: 53
# RIPPLE NR: 595
# ---- CHUNK: 53
# RIPPLE NR: 596
# ---- CHUNK: 53
# RIPPLE NR: 597
# ---- CHUNK: 53
# RIPPLE NR: 598
# ---- CHUNK: 53
# RIPPLE NR: 599
# ---- CHUNK: 55
# RIPPLE NR: 600
# ---- CHUNK: 55
# RIPPLE NR: 601
# ---- CHUNK: 59
# RIPPLE NR: 602
# ---- CHUNK: 59
# RIPPLE NR: 603
# ---- CHUNK: 60
# RIPPLE NR: 604
# ---- CHUNK: 60
# RIPPLE NR: 605
# ---- CHUNK: 60
# RIPPLE NR: 606
# ---- CHUNK: 60
# RIPPLE NR: 607
# ---- CHUNK: 60
# RIPPLE NR: 608
# ---- CHUNK: 60
# RIPPLE NR: 609
# ---- CHUNK: 61
# RIPPLE NR: 610
# ---- CHUNK: 61
# RIPPLE NR: 611
# ---- CHUNK: 64
# RIPPLE NR: 612
# ---- CHUNK: 65
# RIPPLE NR: 613
# ---- CHUNK: 65
# RIPPLE NR: 614
# ---- CHUNK: 66
# RIPPLE NR: 615
# ---- CHUNK: 67
# RIPPLE NR: 616
# ---- CHUNK: 68
# RIPPLE NR: 617
# ---- CHUNK: 69
# RIPPLE NR: 618
# ---- CHUNK: 69
# RIPPLE NR: 619
# ---- CHUNK: 71
# RIPPLE NR: 620
# ---- CHUNK: 72
# RIPPLE NR: 621
# ---- CHUNK: 73
# RIPPLE NR: 622
# ---- CHUNK: 74
# RIPPLE NR: 623
# ---- CHUNK: 74
# RIPPLE NR: 624
# ---- CHUNK: 75
# RIPPLE NR: 625
# ---- CHUNK: 78
# RIPPLE NR: 626
# ---- CHUNK: 8
# RIPPLE NR: 627
# ---- CHUNK: 8
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[217], line 8
#       5     ripple_cg_data = collect_cg_data_for_ripple(row)
#       6     data_list.append(ripple_cg_data)
# ----> 8 cg_data = pd.contact(data_list)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'contact'

# %%
cg_data = pd.concat(data_list).reset_index()
cg_data.head()
# Out:
#    ripple_nr  timestamp      TT1      TT2      TT3      TT4      TT5      TT6  \
# 0          0   83.25725  151.905  105.105  158.730  191.685  -38.610  121.485
# 1          0   83.25775  144.495  125.190  151.515  148.980  -86.775  116.415
# 2          0   83.25825   76.440   95.940  108.420  106.470 -139.620   68.250
# 3          0   83.25875    0.000   17.160   54.990   18.525 -220.155  -26.715
# 4          0   83.25925  -20.280  -10.920   28.665   15.795 -262.470  -54.015
#
#        TT7      TT8      TT9     TT10     TT11    TT12    TT13    TT14
# 0  115.245  146.835  149.760  147.225    8.970  73.905  37.830  70.590
# 1  108.420  145.470  145.080  130.455    7.020  70.785  44.070  67.275
# 2   33.150  111.735  109.590   75.855  -79.755  15.405  12.870  23.010
# 3  -52.455   40.365   65.520   -0.780 -129.870 -38.610 -71.955 -40.365
# 4  -74.685   16.380   18.915  -39.585 -130.650 -69.615 -82.485 -88.140

# %%
print('Shape of dataframe: {}'.format(cg_data.shape))
print('Number of ripples: {}'.format(cg_data.ripple_nr.nunique()))
# Out:
# Shape of dataframe: (1809626, 16)
# Number of ripples: 628

# %% [markdown]
# <br>
#
# ### Drop dead channels
#
#  MAG: TT6?

# %% [markdown]
# <br>
#
# ### Prepare dataset for storage

# %%
ripple_info = ripples_analysis[['ripple_nr', 'start_time', 'end_time', 'phase']]

# %%
cg_data_all = pd.merge(
    cg_data, 
    ripple_info, 
    left_on=['ripple_nr'], 
    right_on='ripple_nr', 
    how='left'
)

# %% [markdown]
# <br>
#
# ### Calculate relative timestamp

# %%
cg_data_all['relative_timestamp']=cg_data_all['timestamp'] - cg_data_all['start_time']

# %%
cg_data_all.head()
# Out:
#    ripple_nr  timestamp      TT1      TT2      TT3      TT4      TT5      TT6  \
# 0          0   83.25725  151.905  105.105  158.730  191.685  -38.610  121.485
# 1          0   83.25775  144.495  125.190  151.515  148.980  -86.775  116.415
# 2          0   83.25825   76.440   95.940  108.420  106.470 -139.620   68.250
# 3          0   83.25875    0.000   17.160   54.990   18.525 -220.155  -26.715
# 4          0   83.25925  -20.280  -10.920   28.665   15.795 -262.470  -54.015
#
#        TT7      TT8      TT9     TT10     TT11    TT12    TT13    TT14  \
# 0  115.245  146.835  149.760  147.225    8.970  73.905  37.830  70.590
# 1  108.420  145.470  145.080  130.455    7.020  70.785  44.070  67.275
# 2   33.150  111.735  109.590   75.855  -79.755  15.405  12.870  23.010
# 3  -52.455   40.365   65.520   -0.780 -129.870 -38.610 -71.955 -40.365
# 4  -74.685   16.380   18.915  -39.585 -130.650 -69.615 -82.485 -88.140
#
#    start_time  end_time   phase  relative_timestamp
# 0    83.75725  83.81275  Sample             -0.5000
# 1    83.75725  83.81275  Sample             -0.4995
# 2    83.75725  83.81275  Sample             -0.4990
# 3    83.75725  83.81275  Sample             -0.4985
# 4    83.75725  83.81275  Sample             -0.4980

# %% [markdown]
# <br>
#
# ### Save data in local folder

# %%
# Save CG data
#cg_data.to_csv(os.path.join(main_path, 'cg_data.csv'))
cg_data_all.to_csv(os.path.join(local_path, 'cg_data.csv'), index=False)

# Save ripple data 
#ripples_analysis.to_csv(os.path.join(main_path, 'cg_analysis_ripple_library.csv'))
ripples_analysis.to_csv(os.path.join(local_path, 'cg_analysis_ripple_library.csv'), index=False)

# %% [markdown]
# <br>
# <br>
# <br>
#
# #### THE END.
