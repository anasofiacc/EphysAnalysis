# %% [markdown]
# <br>
#
# # Ripple-associated amplitude changes

# %% [markdown]
# The forth notebook is used to analyse putative ripple-associated CG amplitude changes (that is, during hippocampal ripple occurrence) in different task contexts. It does so by:
#
# - Plotting the averaged amplitude (uV) before and after ripple occurrence during different task phases or contexts;
# - Calculating the baselined voltage before and after ripple occurrence
# - Plotting amplitude for all SWR events in a heatmap;
# - Significance testing of observed changes to baseline.

# %% [markdown]
# <br>
#
# ### Imports

# %%
import pandas as pd
import os
import re
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pingouin as pg
import scipy
from scipy.stats import zscore

#import scikit_posthocs as sp
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Colors and specs

# %%
colors = sns.color_palette('Spectral', 14)
plot_context='talk'
#phase_palette = [colors[1], colors[4], colors[10], colors[12]]
phase_palette = [
    "#dc267f",  # Pink
    "#ffb000", # Yellow
    "#785ef0",  # Purple
    "#648fff"  # Blue
]
phases = ['ITI', 'Sample', 'Delay', 'Test']

# %% [markdown]
# <br>
#
# ### Open datasets

# %%
main_path = 'PreProcessedData'
cg_data = pd.read_csv(os.path.join(main_path, 'cg_data.csv'), index_col=False)
ripple_data = pd.read_csv(os.path.join(main_path, 'cg_analysis_ripple_library.csv'), index_col=False)

# %% [markdown]
# <br>
#
# ### Inspect dataset

# %%
cg_data.ripple_nr.nunique()
# Out:
# 1578

# %%
cg_data.head()
# Out:
#    ripple_nr  timestamp      TT1     TT10     TT11     TT12     TT13     TT14  \
# 0          0  551.08405  152.880   84.240  103.350  135.135  121.875  112.710
# 1          0  551.08425  168.675   90.480  128.115  151.905  126.555  125.385
# 2          0  551.08445  178.230  100.230  156.195  150.150  131.235  129.870
# 3          0  551.08465  191.100   99.645  160.095  144.495  135.135  141.765
# 4          0  551.08485  186.225  107.640  160.875  156.390  156.585  174.135
#
#        TT2      TT3  ...      TT5      TT6      TT7     TT8      TT9  \
# 0  162.435  119.925  ...  199.680  222.885  179.205  129.09  127.725
# 1  179.400  158.925  ...  206.700  245.310  192.465  145.47  151.905
# 2  191.685  177.450  ...  238.290  253.500  201.240  134.94  160.485
# 3  197.340  195.780  ...  246.675  245.895  213.720  146.25  179.400
# 4  212.160  202.605  ...  254.670  240.630  206.310  170.04  167.700
#
#    start_time   end_time               phase    session_code  \
# 0   552.08405  552.14605  Test (Past-choice)  20191113131818
# 1   552.08405  552.14605  Test (Past-choice)  20191113131818
# 2   552.08405  552.14605  Test (Past-choice)  20191113131818
# 3   552.08405  552.14605  Test (Past-choice)  20191113131818
# 4   552.08405  552.14605  Test (Past-choice)  20191113131818
#
#    relative_timestamp
# 0             -1.0000
# 1             -0.9998
# 2             -0.9996
# 3             -0.9994
# 4             -0.9992
#
# [5 rows x 21 columns]

# %% [markdown]
# <br>
#
# ### Perform transformations on dataset

# %% [markdown]
# ##### Tranform to long format

# %%
tt_columns=['TT{}'.format(x) for x in range(1,14)]

# %%
data = cg_data.melt(
    id_vars=['ripple_nr', 'timestamp', 'relative_timestamp', 'start_time', 'phase'],
    value_vars=tt_columns,
    var_name = 'TT',
    value_name='voltage'
)

# %% [markdown]
# #### Define relative time bins with bin centers to plot (10 ms bins)

# %%
# defining the bin edges (can't use range with floats)
bins=[float(x/100) for x in [*range(-50, 50, 1)]]
# bin the relative timestamp column (10 ms bins)
data['bins'] = pd.cut(data['relative_timestamp'], bins)
data["bin_centres"] = pd.to_numeric(data["bins"].apply(lambda x: x.mid))

# Drop edge datapoints with no bin
data = data.dropna()
data.head()
# Out:
#       ripple_nr  timestamp  relative_timestamp  start_time  \
# 2501          0  551.58425             -0.4998   552.08405
# 2502          0  551.58445             -0.4996   552.08405
# 2503          0  551.58465             -0.4994   552.08405
# 2504          0  551.58485             -0.4992   552.08405
# 2505          0  551.58505             -0.4990   552.08405
#
#                    phase   TT  voltage           bins  bin_centres
# 2501  Test (Past-choice)  TT1   26.715  (-0.5, -0.49]       -0.495
# 2502  Test (Past-choice)  TT1   31.785  (-0.5, -0.49]       -0.495
# 2503  Test (Past-choice)  TT1   25.350  (-0.5, -0.49]       -0.495
# 2504  Test (Past-choice)  TT1   28.665  (-0.5, -0.49]       -0.495
# 2505  Test (Past-choice)  TT1   30.030  (-0.5, -0.49]       -0.495

# %% [markdown]
# <br>
#
# #### Combine pre-choice and post-choice test phase

# %%
data.loc[(data['phase']=='Test (Pre-choice)')|(data['phase']=='Test (Past-choice)'), 'phase']='Test'

# %%
len(data)
# Out:
# 77504314

# %% [markdown]
# ### Z-score amplitude changes per event
# Mean and Standard deviations used per tetrode
# Substitute z-score values above 3 with the mean

# %%
def zscore_voltage_by_ripple(data):
    # Efficiently compute z-scores by avoiding loops
    zscored_voltage = data.groupby(['ripple_nr', 'TT'])['voltage'].transform(lambda x: (x - x.mean()) / x.std())
    
    print('Outlier detection...')
    # Define outlier condition once
    outlier_condition = zscored_voltage.abs() > 2.5
    print(outlier_condition.sum())
    
    print('Outlier removal')
    # For outliers, replace with mean z-score of respective ripple_nr and TT
    data['zscored_voltage'] = zscored_voltage.where(
        ~outlier_condition, zscored_voltage.groupby([data['ripple_nr'], data['TT']]).transform('mean'))
    
    return data

# %%
z_data = zscore_voltage_by_ripple(data)
# Out:
# Outlier detection...
# 952408
# Outlier removal

# %%
100*(952408/len(data))
# Out:
# 1.228845145316685

# %%
z_data.head()
# Out:
#       ripple_nr  timestamp  relative_timestamp  start_time phase   TT  \
# 2501          0  551.58425             -0.4998   552.08405  Test  TT1
# 2502          0  551.58445             -0.4996   552.08405  Test  TT1
# 2503          0  551.58465             -0.4994   552.08405  Test  TT1
# 2504          0  551.58485             -0.4992   552.08405  Test  TT1
# 2505          0  551.58505             -0.4990   552.08405  Test  TT1
#
#       voltage           bins  bin_centres  zscored_voltage
# 2501   26.715  (-0.5, -0.49]       -0.495         0.210765
# 2502   31.785  (-0.5, -0.49]       -0.495         0.270592
# 2503   25.350  (-0.5, -0.49]       -0.495         0.194658
# 2504   28.665  (-0.5, -0.49]       -0.495         0.233776
# 2505   30.030  (-0.5, -0.49]       -0.495         0.249883

# %%
# Stored without outlier removal
#z_data.to_csv(
#    os.path.join(main_path,'cg_z_data.csv'), 
#    index=False
#)

# %% [markdown]
# <br>
#
# ### Plot averaged amplitude changes

# %%
def plot_avg_voltage(data, color, ycol):
    
    # Set style and context
    sns.set(context='talk', style='white')    
    # Create a figure
    plt.figure(dpi=300, figsize=(8, 4))

    # Plot the mean line on top
    sns.lineplot(
        data=data,
        x='bin_centres',
        y=ycol,
        hue='phase',
        hue_order=['ITI', 'Sample', 'Delay', 'Test'],
        errorbar='ci',
        estimator='mean',
        color=color,
        n_boot = 2, #50,
        seed = 1,
        linewidth=1,
        palette = color# Thicker line for the mean
    )

    # Improve labels
    plt.xlabel('Time (s)')
    plt.ylabel('Voltage (uV)')
    plt.xticks(rotation=0)
    plt.legend(frameon=False, bbox_to_anchor=(1.1, 1))
    plt.ylim([-0.2, 0.2])
    plt.xlim([-0.4, 0.4])

    # Add vertical bar to SWR onset (relative_timestamp = 0)
    plt.axvline(x=0, color='black', linestyle='dotted', linewidth=2)

    sns.despine()

# %%
plot_avg_voltage(z_data, phase_palette, 'zscored_voltage')

# Define the directory and filename
directory = '/Users/bgoncalves/Desktop/Sofia - PhD/SVG Figures'
filename = 'F3_A.svg'

# Save the figure as an SVG file
fig = plt.gcf()  # Get the current figure
fig.savefig(os.path.join(directory, filename), format='svg')

plt.show()

# %%
#plot_avg_voltage(data, phase_palette, 'voltage')

# %%
def plot_voltage_distributions(data, color, ycol):
    
    # Set style and context
    sns.set(context='talk', style='white')    
    
    # Create a figure
    plt.figure(dpi=300, figsize=(8, 4))

    # Plot the median line
    lineplot =sns.lineplot(
        data=data,
        x='bin_centres',
        y=ycol,
        hue='phase',
        hue_order=['ITI', 'Sample', 'Delay', 'Test'],
        estimator='median',
        errorbar = ('pi', 50),
        err_kws = {'alpha': .05,  'linewidth': 0 },
        linewidth=1,
        palette=color
    )

    # Improve labels
    plt.xlabel('Time (s)')
    plt.ylabel('Voltage (uV)')
    plt.xlim([-0.4,0.4])
    plt.ylim([-1.5,1.5])
    plt.xticks(rotation=0)
    plt.legend(frameon=False, bbox_to_anchor=(1.3, 1))
    

    # Add vertical bars to mark specific timepoints (SWR onset and others)
    plt.axvline(x=0, color='black', linestyle='dotted', linewidth=2)
    
    plt.axvline(x=-0.09,color='darkgray', linestyle='dotted', linewidth=2)
    plt.axvline(x=0.05, color='darkgray', linestyle='dotted', linewidth=2)   
    
    plt.ylim([-1,1])
    sns.despine()

# %%
plot_voltage_distributions(z_data, phase_palette, 'zscored_voltage')
# Define the directory and filename
directory = '/Users/bgoncalves/Desktop/Sofia - PhD/SVG Figures'
filename = 'F3_B.svg'

# Save the figure as an SVG file
fig = plt.gcf()  # Get the current figure
fig.savefig(os.path.join(directory, filename), format='svg')
plt.show()

# %% [markdown]
# <br>
# <br>
#
# ## Comparing ERP windows
#
# Pre-onset period baseline to  previous baseline period average
# Post onset baselined to previous period average.

# %%
def calculate_and_plot_zscored_differences(data, comparisons, palette='viridis', bins = 60):
    # Initialize list for storing results
    results = []

    # Iterate through each unique phase
    for phase in data['phase'].unique():
        phase_data = data[data['phase'] == phase]

        # Pivot data to get each timepoint's zscored_voltage for each ripple_nr and TT
        pivoted_data = phase_data.pivot(index=['ripple_nr'], columns='timepoint', values='zscored_voltage')
        
        
        # Calculate specified comparisons
        comparison_data = {}
        for comparison in comparisons:
            timepoint_1, timepoint_2 = comparison
            comparison_name = f'{timepoint_1}_vs_{timepoint_2}'
            comparison_data[comparison_name] = pivoted_data[timepoint_2] - pivoted_data[timepoint_1]
        
        # Convert comparison_data into a DataFrame
        comparison_df = pd.DataFrame(comparison_data)

        # Add phase column to comparison_df
        comparison_df['phase'] = phase

        # Append to results
        results.append(comparison_df)

    # Concatenate results from all phases
    results_df = pd.concat(results).reset_index()

    # Set histogram parameters
    bin_width = (results_df.iloc[:, 0].max() - results_df.iloc[:, 0].min()) / bins  # Assuming the first comparison column for bin width
    print(f'Bin width for histograms: {bin_width:.2f} uV')

    # Create histograms for each comparison
    plt.figure(dpi=300, figsize=(8, 4))  
    sns.set_context('talk')
    
    for i, comparison in enumerate(comparisons):
        comparison_name = f'{comparison[0]}_vs_{comparison[1]}'

        # Plot histogram for each comparison
        plt.subplot(len(comparisons), 1, i + 1)
        sns.histplot(data=results_df, x=comparison_name, 
                     hue='phase', bins=bins, palette=palette, stat='count',
                     hue_order= ['ITI','Sample','Delay', 'Test'],
                     alpha=0.01, element='step', legend=False, linewidth=1.2)
        plt.title(f'{comparison[0]} vs. {comparison[1]} Differences')
        
        plt.xlabel('Voltage (uV)')
        plt.ylabel('Count')
        sns.despine()
        
        
    plt.axvline(0, linestyle='dotted', color='black', linewidth=2)    
    plt.tight_layout()
    plt.show()
    

    # Cumulative quantile plot for each comparison
    for comparison in comparisons:
        comparison_name = f'{comparison[0]}_vs_{comparison[1]}'

        plt.figure(dpi=300, figsize=(8, 4))  # Shortened height
        sns.set_context('talk')
        
        sns.ecdfplot(data=results_df, x=comparison_name, hue='phase', 
                     hue_order= ['ITI','Sample','Delay', 'Test'],
                     palette=palette, linewidth=1.5, legend=False)
        
        plt.xlabel('Voltage (uV)')
        plt.ylabel('Probability')
        plt.xlim([-1.5,1.2])

        # Add median vertical lines for each phase
        for i, phase in enumerate(['ITI','Sample','Delay', 'Test']):
            median_value = results_df.loc[results_df['phase'] == phase, comparison_name].median()
            plt.axvline(median_value, linestyle='solid', color=palette[i], linewidth=1.2)
        
        plt.axvline(0, linestyle='dotted', color='black', linewidth=1)
        
        sns.despine()

    return results_df

# %%
# given exclusion period is 500 ms and I want to avoid any post-ripple effects from potential previous events
z_data.loc[(z_data.bin_centres >= -0.095) & (z_data.bin_centres <= -0.005), 'timepoint'] = 'Baseline'
z_data.loc[(z_data.bin_centres >= 0.005) & (z_data.bin_centres <= 0.045), 'timepoint'] = 'SOI' 

z_data.loc[(z_data.bin_centres < -0.095), 'timepoint'] = np.nan
z_data.loc[(z_data.bin_centres > 0.045), 'timepoint'] = np.nan

# %%
# Between -100 ms to 0 ms
z_data.loc[z_data.relative_timestamp.between(-0.10, -0.001), 'bin_centres'].unique()
# Out:
# array([-0.095, -0.085, -0.075, -0.065, -0.055, -0.045, -0.035, -0.025,
#        -0.015, -0.005])

# %%
# Between 0 ms to 50 ms
z_data.loc[z_data.relative_timestamp.between(0.0001, 0.05), 'bin_centres'].unique()
# Out:
# array([0.005, 0.015, 0.025, 0.035, 0.045])

# %%
window_data = z_data.groupby(['phase', 'ripple_nr','timepoint'])['zscored_voltage'].mean().reset_index()

# %%
window_data.timepoint.unique()
# Out:
# array(['Baseline', 'SOI'], dtype=object)

# %%
# Define the comparisons you want to make
comparisons = [('Baseline', 'SOI')]

timepoint_differences = calculate_and_plot_zscored_differences(
    window_data, palette=phase_palette, comparisons=comparisons, bins=52
)

# Define the directory and filename
#directory = '/Users/bgoncalves/Desktop/Sofia - PhD/SVG Figures'
#filename = 'F3_CD.svg'

# Save the figure as an SVG file
#fig = plt.gcf()  # Get the current figure
#fig.savefig(os.path.join(directory, filename), format='svg')
#plt.show()
# Out:
# Bin width for histograms: 30.33 uV

# %%
timepoint_differences.groupby(['phase'])['Baseline_vs_SOI'].describe()
# Out:
#         count      mean       std       min       25%       50%       75%  \
# phase
# Delay   346.0 -0.102625  0.575719 -1.709820 -0.476055 -0.096544  0.264718
# ITI     296.0 -0.102595  0.534193 -1.998079 -0.415198 -0.131877  0.255000
# Sample  515.0 -0.047985  0.580943 -1.648837 -0.399786 -0.074783  0.313737
# Test    421.0 -0.049025  0.584145 -1.838327 -0.473242 -0.039649  0.339315
#
#              max
# phase
# Delay   1.607387
# ITI     1.159113
# Sample  1.712766
# Test    1.540303

# %% [markdown]
# ## Statistical testing
# Compare Baseline vs. Pre vs. Post to determine effect of time/swr onset within and across phases

# %%
for phase in ['ITI', 'Sample', 'Delay', 'Test']:
    data = timepoint_differences.loc[timepoint_differences.phase == phase, 'Baseline_vs_SOI']
    
    # Perform Wilcoxon signed-rank test
    wilcoxon_stat, wilcoxon_p = scipy.stats.wilcoxon(data)
       
    # Print results with bonferroni correction (x4)
    print(f'{phase} : Wilcoxon stat={wilcoxon_stat}, p={wilcoxon_p*4}')
# Out:
# ITI : Wilcoxon stat=17333.0, p=0.00649371845552418
# Sample : Wilcoxon stat=59644.0, p=0.1777531756453493
# Delay : Wilcoxon stat=23889.0, p=0.004001806698388024
# Test : Wilcoxon stat=40195.0, p=0.3644938070295919

# %% [markdown]
# #### Re-create distribution plots above for sample only (the only significant result)

# %%
def calculate_and_plot_zscored_differences_phase(data, phase, comparisons, color='black', bins=60):

    # Filter data for the specified phase
    phase_data = data[data['phase'] == phase]
    
    # Pivot data to get each timepoint's z-scored voltage for each ripple_nr
    pivoted_data = phase_data.pivot(index=['ripple_nr'], columns='timepoint', values='zscored_voltage')
    
    # Calculate specified comparisons
    comparison_data = {}
    for timepoint_1, timepoint_2 in comparisons:
        comparison_name = f'{timepoint_1}_vs_{timepoint_2}'
        comparison_data[comparison_name] = pivoted_data[timepoint_2] - pivoted_data[timepoint_1]
    
    # Convert comparison_data into a DataFrame
    comparison_df = pd.DataFrame(comparison_data)
    
    # Add phase column to comparison_df
    comparison_df['phase'] = phase
    
    # Set histogram parameters
    bin_width = ((comparison_df.iloc[:, 0].max() - comparison_df.iloc[:, 0].min()) / bins)*100
    print(f'Bin width for histograms: {bin_width:.2f} uV')
    
    # Create histograms for each comparison
    #plt.figure(dpi=300, figsize=(6, 4))  
    #sns.set_context('talk')
    
    #for i, (timepoint_1, timepoint_2) in enumerate(comparisons):
    #    comparison_name = f'{timepoint_1}_vs_{timepoint_2}'
        
    #    plt.subplot(len(comparisons), 1, i + 1)
    #    sns.histplot(data=comparison_df, x=comparison_name, bins=bins, 
    #                 color=color, stat='count',
    #                 alpha=0.05, element='step', linewidth=1.5)
        
    #    plt.xlabel('Voltage (uV)')
    #   plt.ylabel('Count')
    #    plt.xlim([-2,2])
    #    sns.despine()
    
    #plt.axvline(0, linestyle='dotted', color='black', linewidth=2)    
    #plt.tight_layout()
    #plt.show()
    
    # Cumulative quantile plot for each comparison
    for timepoint_1, timepoint_2 in comparisons:
        comparison_name = f'{timepoint_1}_vs_{timepoint_2}'

        plt.figure(dpi=300, figsize=(6, 4))
        sns.set_context('talk')
        
        sns.ecdfplot(data=comparison_df, x=comparison_name, color=color, linewidth=1.5)
        plt.xlabel('Voltage (uV)')
        plt.ylabel('Probability')
        plt.xlim([-1.5, 1.2])
        
        # Add median vertical line
        median_value = comparison_df[comparison_name].median()
        plt.axvline(median_value, linestyle='solid', color=color, linewidth=1.2)
        
        plt.axvline(0, linestyle='dotted', color='black', linewidth=2)
        sns.despine()
    
    return comparison_df

# %%
# Define the comparisons you want to make
comparisons = [('Baseline', 'SOI')]

calculate_and_plot_zscored_differences_phase(window_data, 'Test', 
                                       color=phase_palette[3], 
                                       comparisons=comparisons, 
                                       bins=25)

# Define the directory and filename
directory = '/Users/bgoncalves/Desktop/Sofia - PhD/SVG Figures'
filename = 'F3_J.svg'
#F3_C/D- ITI, F3_E/F -Sample, F3_G/H - Delay, F3_I/J - Test
# Save the figure as an SVG file
fig = plt.gcf()  # Get the current figure
fig.savefig(os.path.join(directory, filename), format='svg')
plt.show()
# Out:
# Bin width for histograms: 13.51 uV

# %% [markdown]
# ##### THE END
